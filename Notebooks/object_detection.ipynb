# %% [markdown]
# # Setup
#
# Clone GitHub [repository](https://github.com/ultralytics/yolov5), install [dependencies](https://github.com/ultralytics/yolov5/blob/master/requirements.txt) and check PyTorch and GPU.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt comet_ml  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.5/78.2 GB disk)

# %%
# !unzip -q ../train_data.zip -d ../

# %% [markdown]
# #train

# %% [markdown]
# ##train dataset1

# %%
# !python train.py --img 640 --batch 16 --epochs 200 --data custom_data1.yaml --weights /content/best.pt --cache --single-cls
# Out:
# train: weights=/content/best.pt, cfg=, data=custom_data1.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=200, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=True, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %% [markdown]
# ##train dataset2

# %%
# !python train.py --img 640 --batch 16 --epochs 200 --data custom_data1.yaml --weights /content/yolov5/runs/train/exp/weights/best.pt --cache --single-cls
# Out:
# train: weights=/content/yolov5/runs/train/exp/weights/best.pt, cfg=, data=custom_data1.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=200, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=True, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
# !python train.py --img 228 --batch 16 --epochs 200 --data custom_data1.yaml --weights /content/yolov5/runs/train/exp7/weights/best.pt --cache --single-cls
# Out:
# train: weights=/content/yolov5/runs/train/exp7/weights/best.pt, cfg=, data=custom_data1.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=200, batch_size=16, imgsz=228, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=True, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %% [markdown]
# ##traindataset3

# %%
# !python train.py --img 640 --batch 16 --epochs 200 --data custom_data1.yaml --weights /content/yolov5/runs/train/exp/weights/best.pt --cache --single-cls
# Out:
# train: weights=/content/yolov5/runs/train/exp/weights/best.pt, cfg=, data=custom_data1.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=200, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=True, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %% [markdown]
# ##train dataset4

# %%
# !python train.py --img 640 --batch 16 --epochs 200 --data custom_data1.yaml --weights yolov5s.pt --cache --single-cls
# Out:
# train: weights=yolov5s.pt, cfg=, data=custom_data1.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=200, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=True, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %% [markdown]
# #train dataset5

# %%
# !python train.py --img 640 --batch 16 --epochs 200 --data custom_data1.yaml --weights yolov5s.pt --cache --single-cls
# Out:
# train: weights=yolov5s.pt, cfg=, data=custom_data1.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=200, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=True, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %% [markdown]
# #Validate

# %% [markdown]
# ##Train set 1

# %%
# !python val.py --weights /content/yolov5/runs/train/exp/weights/best.pt --data custom_data1.yaml --img 640
# Out:
# val: data=/content/yolov5/data/custom_data1.yaml, weights=['/content/yolov5/runs/train/exp/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 212 layers, 20852934 parameters, 0 gradients, 47.9 GFLOPs
# val: Scanning /content/drive/MyDrive/Auto WCEBleedGen Challenge Dataset/Train Dataset/WCEBleedGen/train_dataset1/labels/val.cache... 50 images, 0 backgrounds, 0 corrupt: 100% 50/50 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:02<00:00,  1.16s/it]
#                    all         50         50      0.554       0.52      0.501      0.238
# ...

# %%
# !python val.py --weights /content/yolov5/runs/train/exp4/weights/best.pt --data custom_data1.yaml --img 640
# Out:
# val: data=/content/yolov5/data/custom_data1.yaml, weights=['/content/yolov5/runs/train/exp4/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 212 layers, 20852934 parameters, 0 gradients, 47.9 GFLOPs
# val: Scanning /content/drive/MyDrive/Auto WCEBleedGen Challenge Dataset/Train Dataset/WCEBleedGen/train_dataset1/labels/val.cache... 50 images, 0 backgrounds, 0 corrupt: 100% 50/50 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:03<00:00,  1.67s/it]
# ...

# %%
# !python val.py --weights /content/yolov5/runs/train/exp5/weights/best.pt --data custom_data1.yaml --img 640
# Out:
# val: data=/content/yolov5/data/custom_data1.yaml, weights=['/content/yolov5/runs/train/exp5/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 212 layers, 20852934 parameters, 0 gradients, 47.9 GFLOPs
# val: Scanning /content/drive/MyDrive/Auto WCEBleedGen Challenge Dataset/Train Dataset/WCEBleedGen/train_dataset1/labels/val.cache... 50 images, 0 backgrounds, 0 corrupt: 100% 50/50 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:02<00:00,  1.23s/it]
# ...

# %%
from PIL import Image
import matplotlib.pyplot as plt
image_path = '/content/yolov5/runs/train/exp/val_batch1_pred.jpg'
img = Image.open(image_path)
#plt.subplot(121)
#plt.imshow(img)
left = 950
upper = 0
right = 1550
lower = 470
cropped_img = img.crop((left, upper, right, lower))
#plt.subplot(122)
plt.imshow(cropped_img)
plt.show()

# %% [markdown]
# #train set2

# %%
from PIL import Image
import matplotlib.pyplot as plt
image_path = '/content/yolov5/runs/train/exp6/val_batch1_pred.jpg'
img = Image.open(image_path)
#plt.subplot(121)
#plt.imshow(img)
left = 0
upper = 0
right = 475
lower = 470
cropped_img = img.crop((left, upper, right, lower))
#plt.subplot(122)
plt.imshow(cropped_img)
plt.show()

# %% [markdown]
# #train set3

# %%
from PIL import Image
import matplotlib.pyplot as plt
image_path = '/content/yolov5/runs/train/exp8/val_batch1_pred.jpg'
img = Image.open(image_path)
#plt.subplot(121)
#plt.imshow(img)
left = 950
upper = 0
right = 1520
lower = 500
cropped_img = img.crop((left, upper, right, lower))
#plt.subplot(122)
plt.imshow(cropped_img)
plt.show()

# %% [markdown]
# #train set4

# %%
from PIL import Image
import matplotlib.pyplot as plt
image_path = '/content/yolov5/runs/train/exp9/val_batch1_pred.jpg'
img = Image.open(image_path)
#plt.subplot(121)
#plt.imshow(img)
left = 1450
upper = 950
right = 1925
lower = 1450
cropped_img = img.crop((left, upper, right, lower))
#plt.subplot(122)
plt.imshow(cropped_img)
plt.show()

# %% [markdown]
# #train set5

# %%
from PIL import Image
import matplotlib.pyplot as plt
image_path = '/content/yolov5/runs/train/exp4/val_batch1_pred.jpg'
img = Image.open(image_path)
#plt.subplot(121)
#plt.imshow(img)
left = 1425
upper = 950
right = 1925
lower = 1450
cropped_img = img.crop((left, upper, right, lower))
#plt.subplot(122)
plt.imshow(cropped_img)
plt.show()

# %% [markdown]
# #Test

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp/weights/best.pt --conf 0.25 --img 640 --source "/content/drive/MyDrive/Test Dataset 1/Test Dataset 1"
# display.Image(filename='runs/detect/exp/zidane.jpg', width=600)
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/drive/MyDrive/Test Dataset 1/Test Dataset 1, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 212 layers, 20852934 parameters, 0 gradients, 47.9 GFLOPs
# image 1/49 /content/drive/MyDrive/Test Dataset 1/Test Dataset 1/A0000.png: 640x640 (no detections), 27.1ms
# image 2/49 /content/drive/MyDrive/Test Dataset 1/Test Dataset 1/A0001.png: 640x640 (no detections), 27.1ms
# ...

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp4/weights/best.pt --conf 0.25 --img 640 --source "/content/drive/MyDrive/Test Dataset 1/Test Dataset 1"
# Out:
# detect: weights=['/content/yolov5/runs/train/exp4/weights/best.pt'], source=/content/drive/MyDrive/Test Dataset 1/Test Dataset 1, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/49 /content/drive/MyDrive/Test Dataset 1/Test Dataset 1/A0000.png: 640x640 (no detections), 11.5ms
# image 2/49 /content/drive/MyDrive/Test Dataset 1/Test Dataset 1/A0001.png: 640x640 (no detections), 11.5ms
# ...

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp2/weights/best.pt --conf 0.25 --img 640 --source "/content/drive/MyDrive/Test Dataset 1/Test Dataset 1"
# Out:
# detect: weights=['/content/yolov5/runs/train/exp2/weights/best.pt'], source=/content/drive/MyDrive/Test Dataset 1/Test Dataset 1, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 212 layers, 20852934 parameters, 0 gradients, 47.9 GFLOPs
# image 1/49 /content/drive/MyDrive/Test Dataset 1/Test Dataset 1/A0000.png: 640x640 (no detections), 27.0ms
# image 2/49 /content/drive/MyDrive/Test Dataset 1/Test Dataset 1/A0001.png: 640x640 (no detections), 27.0ms
# ...

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp3/weights/best.pt --conf 0.25 --img 640 --source "/content/drive/MyDrive/Test Dataset 1/Test Dataset 1"
# Out:
# detect: weights=['/content/yolov5/runs/train/exp3/weights/best.pt'], source=/content/drive/MyDrive/Test Dataset 1/Test Dataset 1, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/49 /content/drive/MyDrive/Test Dataset 1/Test Dataset 1/A0000.png: 640x640 (no detections), 11.5ms
# image 2/49 /content/drive/MyDrive/Test Dataset 1/Test Dataset 1/A0001.png: 640x640 (no detections), 11.5ms
# ...

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp/weights/best.pt --conf 0.25 --img 640 --source "/content/drive/MyDrive/Test Dataset 2/Test Dataset 2"
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/drive/MyDrive/Test Dataset 2/Test Dataset 2, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 212 layers, 20852934 parameters, 0 gradients, 47.9 GFLOPs
# image 1/515 /content/drive/MyDrive/Test Dataset 2/Test Dataset 2/A0050.png: 640x640 (no detections), 27.1ms
# image 2/515 /content/drive/MyDrive/Test Dataset 2/Test Dataset 2/A0051.png: 640x640 (no detections), 27.1ms
# ...

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp2/weights/best.pt --conf 0.25 --img 640 --source "/content/drive/MyDrive/Test Dataset 2/Test Dataset 2"
# Out:
# detect: weights=['/content/yolov5/runs/train/exp2/weights/best.pt'], source=/content/drive/MyDrive/Test Dataset 2/Test Dataset 2, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 212 layers, 20852934 parameters, 0 gradients, 47.9 GFLOPs
# image 1/515 /content/drive/MyDrive/Test Dataset 2/Test Dataset 2/A0050.png: 640x640 (no detections), 27.0ms
# image 2/515 /content/drive/MyDrive/Test Dataset 2/Test Dataset 2/A0051.png: 640x640 (no detections), 27.0ms
# ...

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp3/weights/best.pt --conf 0.25 --img 640 --source "/content/drive/MyDrive/Test Dataset 2/Test Dataset 2"
# Out:
# detect: weights=['/content/yolov5/runs/train/exp3/weights/best.pt'], source=/content/drive/MyDrive/Test Dataset 2/Test Dataset 2, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/515 /content/drive/MyDrive/Test Dataset 2/Test Dataset 2/A0050.png: 640x640 (no detections), 11.5ms
# image 2/515 /content/drive/MyDrive/Test Dataset 2/Test Dataset 2/A0051.png: 640x640 (no detections), 11.5ms
# ...

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp4/weights/best.pt --conf 0.25 --img 640 --source "/content/drive/MyDrive/Test Dataset 2/Test Dataset 2"
# Out:
# detect: weights=['/content/yolov5/runs/train/exp4/weights/best.pt'], source=/content/drive/MyDrive/Test Dataset 2/Test Dataset 2, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-226-gdd9e338 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/515 /content/drive/MyDrive/Test Dataset 2/Test Dataset 2/A0050.png: 640x640 (no detections), 11.5ms
# image 2/515 /content/drive/MyDrive/Test Dataset 2/Test Dataset 2/A0051.png: 640x640 (no detections), 11.6ms
# ...

# %% [markdown]
# ##test dataset1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##test data2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
